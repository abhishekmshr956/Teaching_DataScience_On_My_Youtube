# %%
# !ls Datasets/developer_survey_2020/
# Out:
# README_2020.txt           survey_results_public.csv
# so_survey_2020.pdf        survey_results_schema.csv

# %%
import pandas as pd
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('Datasets/developer_survey_2020/survey_results_public.csv', index_col ='Respondent', na_values=na_vals)
schema_df = pd.read_csv('Datasets/developer_survey_2020/survey_results_schema.csv', index_col = 'Column')

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
schema_df.loc['YearsCode','QuestionText']
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
df['YearsCode'].replace({'Less than 1 year' : 0, 'More than 50 years':51}, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %%
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
india_df.to_csv('Datasets/developer_survey_2020/modified.csv')

# %%
india_df.to_csv('Datasets/developer_survey_2020/modified.tsv', sep='\t')

# %%
india_df.to_excel('Datasets/developer_survey_2020/modified.xlsx')

# %%
test = pd.read_excel('Datasets/developer_survey_2020/modified.xlsx',index_col='Respondent')

# %%
#test
